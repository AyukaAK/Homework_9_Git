# %% [markdown]
# # Scrape
#
# https://www.marylandpublicschools.org/stateboard/Pages/Meetings-2018.aspx (Links to an external site.)
#
# Tier 1: Scrape the date, URL to agenda, URL to board minutes
#
# Tier 2: Download agenda items to an "agendas" folder and board minutes to a "minutes" folder

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
response = requests.get("https://www.marylandpublicschools.org/stateboard/Pages/Meetings-2018.aspx")
doc = BeautifulSoup(response.text)

# %%
print(doc.prettify())
# Out:
# <!DOCTYPE HTML>
# <html class="ms-isBot" dir="ltr" lang="en-US">
#  <head>
#   <meta content="SharePoint.WebPartPage.Document" name="progid"/>
#   <meta content="0" http-equiv="Expires"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1, user-scalable=0" name="viewport"/>
#   <!-- ============== Robots  ======================================================================================================= -->
#   <!-- ============== Favicon / Windows Tile ======================================================================================== -->
#   <!-- ============== Page Title loaded from page or page layout ==================================================================== -->
#   <title>
#    State Board 2018 Meeting Calendar, Agendas, &amp; Minutes
#   </title>
#   <!-- ============== SP Scripts and CSS  =========================================================================================== -->
#   <link href="/_layouts/15/1033/styles/Themable/corev15.css?rev=2bpHeX9U8DH09TB5zpJcsQ%3D%3D" rel="stylesheet" type="text/css"/>
#   <link href="/Style%20Library/en-US/Themable/Core%20Styles/pagelayouts15.css" rel="stylesheet" type="text/css"/>
#   <script src="/_layouts/15/init.js?rev=R500FBwHjH3TO5LeC6KbFQ%3D%3D" type="text/javascript">
#   </script>
#   <script src="/ScriptResource.axd?d=Emfw0NGuvfySi0YwcIJf5qA-QoeSAfusqqi-mFTrzAt-bnnA2blCXN_m2fb1kN0IBtTJC5U3AbG9eGuxhAJMrM8lAaPcLjcEpo1L6pTLhN50CQ6imxVxbOk-CpTitYD8caL_uHHHoDv7e9WtvBbAkbU2BKeNytDkYqoUuW7pLfMfsJoQaW1vvtNRPxcy0aCE0&amp;t=49337fe8" type="text/javascript">
#   </script>
#   <script src="/_layouts/15/blank.js?rev=ZaOXZEobVwykPO9g8hq%2F8A%3D%3D" type="text/javascript">
#   </script>
#   <script src="/style%20library/egov/js/responsivenavmd.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    RegisterSod("initstrings.js", "\u002f_layouts\u002f15\u002f1033\u002finitstrings.js?rev=S11vfGURQYVuACMEY0tLTg\u00253D\u00253D");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("strings.js", "\u002f_layouts\u002f15\u002f1033\u002fstrings.js?rev=xXYZY4hciX287lShPZuClw\u00253D\u00253D");RegisterSodDep("strings.js", "initstrings.js");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("sp.init.js", "\u002f_layouts\u002f15\u002fsp.init.js?rev=jvJC3Kl5gbORaLtf7kxULQ\u00253D\u00253D");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("sp.res.resx", "\u002f_layouts\u002f15\u002fScriptResx.ashx?culture=en\u00252Dus\u0026name=SP\u00252ERes\u0026rev=yNk\u00252FhRzgBn40LJVP\u00252BqfgdQ\u00253D\u00253D");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("sp.ui.dialog.js", "\u002f_layouts\u002f15\u002fsp.ui.dialog.js?rev=3Oh2QbaaiXSb7ldu2zd6QQ\u00253D\u00253D");RegisterSodDep("sp.ui.dialog.js", "sp.init.js");RegisterSodDep("sp.ui.dialog.js", "sp.res.resx");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("core.js", "\u002f_layouts\u002f15\u002fcore.js?rev=GpU7vxyOqzS0F9OfEX3CCw\u00253D\u00253D");RegisterSodDep("core.js", "strings.js");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("menu.js", "\u002f_layouts\u002f15\u002fmenu.js?rev=cXv35JACAh0ZCqUwKU592w\u00253D\u00253D");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("mQuery.js", "\u002f_layouts\u002f15\u002fmquery.js?rev=VYAJYBo5H8I3gVSL3MzD6A\u00253D\u00253D");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("callout.js", "\u002f_layouts\u002f15\u002fcallout.js?rev=ryx2n4ePkYj1\u00252FALmcsXZfA\u00253D\u00253D");RegisterSodDep("callout.js", "strings.js");RegisterSodDep("callout.js", "mQuery.js");RegisterSodDep("callout.js", "core.js");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("clienttemplates.js", "\u002f_layouts\u002f15\u002fclienttemplates.js?rev=NjHQZTfQs\u00252BiDIjz4PK\u00252FeWg\u00253D\u00253D");RegisterSodDep("clienttemplates.js", "initstrings.js");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("sharing.js", "\u002f_layouts\u002f15\u002fsharing.js?rev=XxxHIxIIc8BsW9ikVc6dgA\u00253D\u00253D");RegisterSodDep("sharing.js", "strings.js");RegisterSodDep("sharing.js", "mQuery.js");RegisterSodDep("sharing.js", "clienttemplates.js");RegisterSodDep("sharing.js", "core.js");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("suitelinks.js", "\u002f_layouts\u002f15\u002fsuitelinks.js?rev=REwVU5jSsadDdOZlCx4wpA\u00253D\u00253D");RegisterSodDep("suitelinks.js", "strings.js");RegisterSodDep("suitelinks.js", "core.js");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("sp.runtime.js", "\u002f_layouts\u002f15\u002fsp.runtime.js?rev=5f2WkYJoaxlIRdwUeg4WEg\u00253D\u00253D");RegisterSodDep("sp.runtime.js", "sp.res.resx");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("sp.js", "\u002f_layouts\u002f15\u002fsp.js?rev=BJ9b7Ak8FOS3NwGiaTXOjA\u00253D\u00253D");RegisterSodDep("sp.js", "sp.runtime.js");RegisterSodDep("sp.js", "sp.ui.dialog.js");RegisterSodDep("sp.js", "sp.res.resx");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("userprofile", "\u002f_layouts\u002f15\u002fsp.userprofiles.js?rev=p5tCOm\u00252FlHUwcfll7W3pKNw\u00253D\u00253D");RegisterSodDep("userprofile", "sp.runtime.js");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("followingcommon.js", "\u002f_layouts\u002f15\u002ffollowingcommon.js?rev=jWqEDmcjCSPmnQw2ZIfItQ\u00253D\u00253D");RegisterSodDep("followingcommon.js", "strings.js");RegisterSodDep("followingcommon.js", "sp.js");RegisterSodDep("followingcommon.js", "userprofile");RegisterSodDep("followingcommon.js", "core.js");RegisterSodDep("followingcommon.js", "mQuery.js");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("profilebrowserscriptres.resx", "\u002f_layouts\u002f15\u002fScriptResx.ashx?culture=en\u00252Dus\u0026name=ProfileBrowserScriptRes\u0026rev=J5HzNnB\u00252FO1Id\u00252FGI18rpRcw\u00253D\u00253D");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("sp.ui.mysitecommon.js", "\u002f_layouts\u002f15\u002fsp.ui.mysitecommon.js?rev=Ua8qmZSU9nyf53S7PEyJwQ\u00253D\u00253D");RegisterSodDep("sp.ui.mysitecommon.js", "sp.init.js");RegisterSodDep("sp.ui.mysitecommon.js", "sp.runtime.js");RegisterSodDep("sp.ui.mysitecommon.js", "userprofile");RegisterSodDep("sp.ui.mysitecommon.js", "profilebrowserscriptres.resx");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("browserScript", "\u002f_layouts\u002f15\u002fnon_ie.js?rev=W2q45TO627Zi6ztdktTOtA\u00253D\u00253D");RegisterSodDep("browserScript", "strings.js");
#   </script>
#   <script type="text/javascript">
#    RegisterSod("inplview", "\u002f_layouts\u002f15\u002finplview.js?rev=iMf5THfqukSYut7sl9HwUg\u00253D\u00253D");RegisterSodDep("inplview", "strings.js");RegisterSodDep("inplview", "core.js");RegisterSodDep("inplview", "sp.js");
#   </script>
#   <link href="/stateboard/_vti_bin/spsdisco.aspx" rel="alternate" type="text/xml"/>
#   <!-- ============== Additional header placeholder - overridden by asp:content on pages or page layouts  =========================== -->
#   <link href="http://www.marylandpublicschools.org:80/stateboard/Pages/Meetings-2018.aspx" rel="canonical"/>
#   <!-- ============== Core SharePoint CSS =========================================================================================== -->
#   <!-- ============== MD Responsive Design Assests =========================================================================================== -->
#   <!--[if lt ie 10]>
# 		<link href="/_layouts/15/MDResponsiveToolKit/egov/css/ie/mdgov_ltie10.css" rel="stylesheet" media="all" />
# 		<![endif]-->
#   <!--[if lt IE 9]>
# 		<script src="/_layouts/15/MDResponsiveToolKit/egov/js/html5shiv.js"></script>
# 		<![endif]-->
#   <!--[if ie 8]>
# 		<link id="ctl00_css_IE8" href="/_layouts/15/MDResponsiveToolKit/egov/css/ie/ie8.css" rel="stylesheet" media="screen" />
# 		<![endif]-->
#   <!--[if ie 7]>
# 		<link id="ctl00_css_IE7" href="/_layouts/15/MDResponsiveToolKit/egov/css/ie/ie7.css" rel="stylesheet" media="screen" />
# 		<![endif]-->
#   <link href="/_layouts/15/MDResponsiveToolKit/egov/frameworks/bootstrap/css/bootstrap.min.css" id="ctl00_Link1" rel="stylesheet" type="text/css"/>
#   <link href="/_layouts/15/MDResponsiveToolKit/egov/css/agency-styles.css" id="ctl00_Link2" rel="stylesheet" type="text/css"/>
#   <link href="/_layouts/15/MDResponsiveToolKit/egov/css/agency-header.css " id="ctl00_Link3" rel="stylesheet" type="text/css"/>
#   <link href="/Style Library/egov/frameworks/Agencysystemstyles.css" id="ctl00_Link4" rel="stylesheet" type="text/css"/>
#   <link href="/Style Library/egov/css/agencystylesadd.css" id="ctl00_Link5" rel="stylesheet" type="text/css"/>
#   <!-- Necessary for navigation UI and Responsive Design -->
#   <script src="/_layouts/15/MDResponsiveToolKit/egov/js/jquery-1.8.2.min.js" type="text/javascript">
#   </script>
#   <!-- Necessary .js for  Statewide nav bar script -->
#   <script src="/_layouts/15/MDResponsiveToolKit/egov/js/yui-min.js">
#   </script>
#   <script src="/_layouts/15/MDResponsiveToolKit/egov/js/jquery-ui-1.10.3.min.js">
#   </script>
#   <!-- Necessary .js  for statewide alerts  -->
#   <script src="/Style Library/egov/js/MDAlertCode.js">
#   </script>
#   <!-- Necessary .js to implement agency search, modify .js with search collection name -->
#   <script src="/Style Library/egov/js/MDSiteSearch.js">
#   </script>
#   <!-- Necessary for responsive navigation links-->
#   <script src="/Style Library/egov/js/ResponsiveNavMD.js" type="text/javascript">
#   </script>
#   <!-- Necessary .js google-analytics -->
#   <script src="/Style Library/egov/js/ua_track_documents_msde.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#        (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#        m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#        })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#        ga('create', 'UA-44468608-15', 'auto');
#        ga('send', 'pageview');
#   </script>
#   <!-- DoIT-FAQ Styles -->
#   <link href="/Style Library/egov/css/DoIT-FAQ-UI.css" id="ctl00_Link6" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <!-- ============== SP IDs / Prefetch SP images / SP Form  =========================================================================== -->
#   <form action="./Meetings-2018.aspx" id="aspnetForm" method="post">
#    <input id="_wpcmWpid" name="_wpcmWpid" type="hidden" value=""/>
#    <input id="wpcmVal" name="wpcmVal" type="hidden" value=""/>
#    <input id="MSOWebPartPage_PostbackSource" name="MSOWebPartPage_PostbackSource" type="hidden" value=""/>
#    <input id="MSOTlPn_SelectedWpId" name="MSOTlPn_SelectedWpId" type="hidden" value=""/>
#    <input id="MSOTlPn_View" name="MSOTlPn_View" type="hidden" value="0"/>
#    <input id="MSOTlPn_ShowSettings" name="MSOTlPn_ShowSettings" type="hidden" value="False"/>
#    <input id="MSOGallery_SelectedLibrary" name="MSOGallery_SelectedLibrary" type="hidden" value=""/>
#    <input id="MSOGallery_FilterString" name="MSOGallery_FilterString" type="hidden" value=""/>
#    <input id="MSOTlPn_Button" name="MSOTlPn_Button" type="hidden" value="none"/>
#    <input id="__REQUESTDIGEST" name="__REQUESTDIGEST" type="hidden" value="0xB08000A00E03B2B42B9E52488C004F50909BE071E8CC62FB17D6A47645FDD95F9225F9F1D57B1D3CABA0AA842A3312EC76BEE0ED9368869FD7D4F5A62BD76A98,14 Jul 2022 19:50:02 -0000"/>
#    <input id="MSOSPWebPartManager_DisplayModeName" name="MSOSPWebPartManager_DisplayModeName" type="hidden" value="Browse"/>
#    <input id="MSOSPWebPartManager_ExitingDesignMode" name="MSOSPWebPartManager_ExitingDesignMode" type="hidden" value="false"/>
#    <input id="MSOWebPartPage_Shared" name="MSOWebPartPage_Shared" type="hidden" value=""/>
#    <input id="MSOLayout_LayoutChanges" name="MSOLayout_LayoutChanges" type="hidden" value=""/>
#    <input id="MSOLayout_InDesignMode" name="MSOLayout_InDesignMode" type="hidden" value=""/>
#    <input id="_wpSelected" name="_wpSelected" type="hidden" value=""/>
#    <input id="_wzSelected" name="_wzSelected" type="hidden" value=""/>
#    <input id="MSOSPWebPartManager_OldDisplayModeName" name="MSOSPWebPartManager_OldDisplayModeName" type="hidden" value="Browse"/>
#    <input id="MSOSPWebPartManager_StartWebPartEditingName" name="MSOSPWebPartManager_StartWebPartEditingName" type="hidden" value="false"/>
#    <input id="MSOSPWebPartManager_EndWebPartEditing" name="MSOSPWebPartManager_EndWebPartEditing" type="hidden" value="false"/>
#    <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
#    <script type="text/javascript">
#     //<![CDATA[
# var MSOWebPartPageFormName = 'aspnetForm';
# var g_presenceEnabled = true;
# var g_wsaEnabled = false;
# var g_wsaQoSEnabled = false;
# var g_wsaQoSDataPoints = [];
# var g_wsaLCID = 1033;
# var g_wsaListTemplateId = 850;
# var g_wsaSiteTemplateId = 'CMSPUBLISHING#0';
# var _fV4UI=true;var _spPageContextInfo = {webServerRelativeUrl: "\u002fstateboard", webAbsoluteUrl: "http:\u002f\u002fwww.marylandpublicschools.org\u002fstateboard", siteAbsoluteUrl: "http:\u002f\u002fwww.marylandpublicschools.org", serverRequestPath: "\u002fstateboard\u002fPages\u002fMeetings-2018.aspx", layoutsUrl: "_layouts\u002f15", webTitle: "State Board", webTemplate: "39", tenantAppVersion: "0", isAppWeb: false, Has2019Era: true, webLogoUrl: "_layouts\u002f15\u002fimages\u002fsiteicon.png", webLanguage: 1033, currentLanguage: 1033, currentUICultureName: "en-US", currentCultureName: "en-US", clientServerTimeDelta: new Date("2022-07-14T19:50:02.2433611Z") - new Date(), siteClientTag: "3643$$15.0.5127.1000", crossDomainPhotosEnabled:false, webUIVersion:15, webPermMasks:{High:16,Low:196673},pageListId:"{64027f88-9b58-4f91-872a-80455082791b}",pageItemId:128, pagePersonalizationScope:1, alertsEnabled:false, siteServerRelativeUrl: "\u002f", allowSilverlightPrompt:'True'};document.onreadystatechange=fnRemoveAllStatus; function fnRemoveAllStatus(){removeAllStatus(true)};//]]>
#    </script>
#    <script src="/_layouts/15/blank.js?rev=ZaOXZEobVwykPO9g8hq%2F8A%3D%3D" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     //<![CDATA[
# (function(){
#
#         if (typeof(_spBodyOnLoadFunctions) === 'undefined' || _spBodyOnLoadFunctions === null) {
#             return;
#         }
#         _spBodyOnLoadFunctions.push(function()
#         {
#           ExecuteOrDelayUntilScriptLoaded(
#             function()
#             {
#               var pairs = SP.ScriptHelpers.getDocumentQueryPairs();
#               var followDoc, itemId, listId, docName;
#               for (var key in pairs)
#               {
#                 if(key.toLowerCase() == 'followdocument')
#                   followDoc = pairs[key];
#                 else if(key.toLowerCase() == 'itemid')
#                   itemId = pairs[key];
#                 else if(key.toLowerCase() == 'listid')
#                   listId = pairs[key];
#                 else if(key.toLowerCase() == 'docname')
#                   docName = decodeURI(pairs[key]);
#               }
#
#               if(followDoc != null && followDoc == '1' && listId!=null && itemId != null && docName != null)
#               {
#                 SP.SOD.executeFunc('followingcommon.js', 'FollowDocumentFromEmail', function()
#                 {
#                   FollowDocumentFromEmail(itemId, listId, docName);
#                 });
#               }
#
#             }, 'SP.init.js');
#
#         });
#     })();(function(){
#
#         if (typeof(_spBodyOnLoadFunctions) === 'undefined' || _spBodyOnLoadFunctions === null) {
#             return;
#         }
#         _spBodyOnLoadFunctions.push(function() {
#
#             if (typeof(SPClientTemplates) === 'undefined' || SPClientTemplates === null || (typeof(APD_InAssetPicker) === 'function' && APD_InAssetPicker())) {
#                 return;
#             }
#
#             var renderFollowFooter = function(renderCtx,  calloutActionMenu)
#             {
#                 if (renderCtx.ListTemplateType == 700)
#                     myDocsActionsMenuPopulator(renderCtx, calloutActionMenu);
#                 else
#                     CalloutOnPostRenderTemplate(renderCtx, calloutActionMenu);
#
#                 var listItem = renderCtx.CurrentItem;
#                 if (typeof(listItem) === 'undefined' || listItem === null) {
#                     return;
#                 }
#                 if (listItem.FSObjType == 0) {
#                     calloutActionMenu.addAction(new CalloutAction({
#                         text: Strings.STS.L_CalloutFollowAction,
#                         tooltip: Strings.STS.L_CalloutFollowAction_Tooltip,
#                         onClickCallback: function (calloutActionClickEvent, calloutAction) {
#                             var callout = GetCalloutFromRenderCtx(renderCtx);
#                             if (!(typeof(callout) === 'undefined' || callout === null))
#                                 callout.close();
#                             SP.SOD.executeFunc('followingcommon.js', 'FollowSelectedDocument', function() { FollowSelectedDocument(renderCtx); });
#                         }
#                     }));
#                 }
#             };
#
#             var registerOverride = function(id) {
#                 var followingOverridePostRenderCtx = {};
#                 followingOverridePostRenderCtx.BaseViewID = 'Callout';
#                 followingOverridePostRenderCtx.ListTemplateType = id;
#                 followingOverridePostRenderCtx.Templates = {};
#                 followingOverridePostRenderCtx.Templates.Footer = function(renderCtx) {
#                     var  renderECB;
#                     if (typeof(isSharedWithMeView) === 'undefined' || isSharedWithMeView === null) {
#                         renderECB = true;
#                     } else {
#                         var viewCtx = getViewCtxFromCalloutCtx(renderCtx);
#                         renderECB = !isSharedWithMeView(viewCtx);
#                     }
#                     return CalloutRenderFooterTemplate(renderCtx, renderFollowFooter, renderECB);
#                 };
#                 SPClientTemplates.TemplateManager.RegisterTemplateOverrides(followingOverridePostRenderCtx);
#             }
#             registerOverride(101);
#             registerOverride(700);
#         });
#     })();if (typeof(DeferWebFormInitCallback) == 'function') DeferWebFormInitCallback();//]]>
#    </script>
#    <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="BAB98CB3"/>
#    <!-- ============== SharePoint Reqs this for adding columns ===================================================== -->
#    <script type="text/javascript">
#     var submitHook = function () { return false; }; theForm._spOldSubmit = theForm.submit; theForm.submit = function () { if (!submitHook()) { this._spOldSubmit(); } };
#    </script>
#    <!-- ============== Web Part Manager  ============================================================================================= -->
#    <!-- ============== ScriptManager ===================================================== -->
#    <!-- ============== Ribbon Code Starts Here ===================================================== -->
#    <div>
#     <div id="s4-ribbonrow" style="visibility:hidden;display:none">
#     </div>
#    </div>
#    <!-- ============== Ribbon Code Ends Here  ======================================================================================== -->
#    <!-- ============== Main Scrolling Body Starts Here =============================================================================== -->
#    <!-- ============== Main Scrolling Body Starts Here =============================================================================== -->
#    <div id="s4-workspace">
#     <div id="s4-bodyContainer">
#      <div class="container" id="MobileNav">
#       <div class="skipNav">
#        <a class="show-on-focus" href="#primary_content_Block">
#         Skip to Main Content
#        </a>
#       </div>
#       <div id="mdgov_globalSiteWrapper">
#        <div class="row-fluid">
#         <div class="clearfix" id="mdgov_TopSliverBar">
#          <div class="clearfix" id="mdgov_TopSliverBarContent">
#           <div id="mdgov_sliverLeft">
#            <div class="hidden-desktop" id="mdgov_mobileNavButton">
#             <a class="show" href="#/">
#              <i class="icon-white icon-align-justify">
#              </i>
#              <span>
#               Menu
#              </span>
#             </a>
#             <a class="hide" href="#MobileNav">
#              <i class="icon-white icon-align-justify">
#              </i>
#              <span>
#               Menu
#              </span>
#             </a>
#            </div>
#           </div>
#           <div id="mdgov_sliverRight">
#            <!-- displays statewide nav bar -->
#            <script type="text/javascript">
#             YUI().use(function (Y) {
#                                                  var url = "https://www.maryland.gov/branding/statewideNavigationDefer2017.js",
# 	             						                obj = Y.Get.script(url, {
# 	             						                    onSuccess: function () {
# 	             						                        document.getElementById('mdgov_sliverRight').innerHTML = showStatewideNavigationWithTranslate("white");
# 	             						                    }
# 	             						                });
#                                              });
#            </script>
#            <noscript>
#             You must have Javascript enabled to see this menu.
#            </noscript>
#            <!-- END statewide nav bar -->
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="row-fluid" id="headerBlock">
#         <div class="span12" id="header">
#          <div id="headerBackground">
#           <div class="headerBgImgSubpage clearfix">
#            <div class="row-fluid">
#             <div class="clearfix" id="agency_branding">
#              <div class="span2 clearfix" id="mdgov_crownLogo">
#               <div id="mdgov_homeLink">
#                <!--  MD Crown logo and link -->
#                <a href="/">
#                 <span class="hidden-accessible">
#                  Maryland.gov Home
#                 </span>
#                </a>
#               </div>
#              </div>
#              <div class="span6 clearfix" id="mdgov_agencyName">
#               <div id="mdgov_agencyTitle">
#                <!--  Add Agency Title and link to home page -->
#                <a href="/">
#                 <img alt="Maryland State Department of Education" src="/Style Library/egov/img/agencyTitle-generic.png"/>
#                </a>
#               </div>
#              </div>
#              <div class="s4-pagedescription" tabindex="-1">
#              </div>
#              <div class="span4 clearfix" id="mdgov_agencyHeader">
#               <div class="clearfix" id="mdgov_enterpriseSearch">
#                <div id="mdgov_enterpriseSearchContainer">
#                 <div id="mdgov_searchInput">
#                  <!-- Step 7 : Agency search code -->
#                  <label class="hidden-accessible" for="searchInputBox">
#                   Search
#                  </label>
#                  <input class="mdgov_searchInputBox" data-placeholder="Enter search term" id="searchInputBox" name="q" onkeypress="return onEnter(event)" type="text"/>
#                  <div class="mdgov_searchButton btn btn-primary searchButtonDiv">
#                   <img alt="Search Maryland" class="fillImageButton" id="searchButton" name="searchButton" onclick="GoogleSearch()" src="/_layouts/15/MDResponsiveToolKit/egov/img/icons/search.png"/>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <!-- End of search code -->
#               <div class="mdgov_socialNav clearfix">
#                <!-- Step 6: Configure Agency social media icons and links -->
#                <ul class="cl_base_hNav cl_socialNav">
#                 <li>
#                  <a class="sm-facebook" href="http://www.facebook.com/MdPublicSchools" title="Facebook">
#                   Facebook
#                  </a>
#                 </li>
#                 <li>
#                  <a class="sm-twitter" href="http://twitter.com/MdPublicSchools" title="Twitter">
#                   Twitter
#                  </a>
#                 </li>
#                 <!--<li><a href="#" class="sm-googleplus" title="Google+">Google Plus</a></li>-->
#                 <li>
#                  <a class="sm-youtube" href="https://www.youtube.com/channel/UCzGBHwAQzzay6lVJafnholw" title="YouTube">
#                   YouTube
#                  </a>
#                 </li>
#                 <!-- <li><a href="" class="sm-flickr" title="Flickr">Flickr</a> </li>-->
#                 <li>
#                  <a class="sm-enewsletter" href="http://marylandpublicschools.org/about/Pages/OCP/Newsroom/index.aspx" title="eNewsletter">
#                   eNewsletter
#                  </a>
#                 </li>
#                 <li>
#                  <a class="sm-all" href="http://www.maryland.gov/pages/social_media.aspx" title="MD Social Media Directory">
#                   Social Media Directory
#                  </a>
#                 </li>
#                </ul>
#                <!--if no Agency social media,replace above UL with code below-->
#                <!--<ul class="cl_base_hNav cl_socialNavDirectory">
#                             			            <li><a href="http://www.maryland.gov/pages/social_media.aspx" class="sm-directory" title="MD Social Media Directory">MD Social Media Directory</a></li>
#                         				            </ul>-->
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <!--Header-->
#        <div class="row-fluid" id="navBlock">
#         <div class="clearfix" id="mdgov_enterpriseNavigation">
#          <!-- Step 9 : Add Main navigation links
#                 following options avaiable for global Navigation
#                 a. StartingRoot="SubsiteName" – identifies whether the Home tab and  start at the subsite or a higher/parent level
#                 b. HideHomeTab="True" – this will suppress the display of the Home tab.
#                 c. HomeTabTitle="Custom Title" Different Title than default
#                 -->
#          <nav>
#           <ul>
#            <li>
#             <a class="level0" href="/Pages/default.aspx" title="Home">
#              Home
#             </a>
#            </li>
#            <li>
#             <a class="level0" href="/about/Pages/default.aspx" title="ABOUT US">
#              ABOUT US
#             </a>
#            </li>
#            <li>
#             <a class="level0" href="/Blueprint/Pages/Overview.aspx" title="The Blueprint">
#              The Blueprint
#             </a>
#            </li>
#            <li id="current">
#             <a class="level0" href="/stateboard/Pages/default.aspx" title="State Board">
#              State Board
#             </a>
#            </li>
#            <li>
#             <a class="level0" href="/programs/Pages/default.aspx" title="Offices/Divisions">
#              Offices/Divisions
#             </a>
#            </li>
#            <li>
#             <a class="level0" href="/newsroom/Pages/default.aspx" title="NewsRoom">
#              NewsRoom
#             </a>
#            </li>
#           </ul>
#          </nav>
#         </div>
#        </div>
#        <noscript>
#         <div class="row-fluid">
#          <div class="uiMessage">
#           <strong>
#            Notice:
#           </strong>
#           JavaScript is not available in your browser. Some enhanced features will not be available until JavaScript is enabled.
#          </div>
#         </div>
#        </noscript>
#        <div class="row-fluid">
#         <div id="primary_content_Block">
#          <div class="span3 leftMargin0" id="primary_left_col">
#           <!--Start primary_left_col-->
#           <div class="mdgov_contentWrapper mdgov_subNav">
#            <section class="primary_left_col_list" id="StateBoard">
#             <header>
#              <h2 data-target="StateBoard">
#               State Board
#              </h2>
#             </header>
#             <div class="subNavWrapper">
#              <ul class="cl_iconNav">
#               <li>
#                <a href="/stateboard/Pages/overview.aspx" title="Overview">
#                 Overview
#                </a>
#               </li>
#               <li>
#                <a href="/stateboard/Pages/State-Board-Updates.aspx" title="State Board Updates">
#                 State Board Updates
#                </a>
#               </li>
#               <li>
#                <a href="/stateboard/Pages/members.aspx" title="State Board Members">
#                 State Board Members
#                </a>
#               </li>
#               <li>
#                <a href="/stateboard/Pages/SBOETeacherMember.aspx" title="Teacher Member Election">
#                 Teacher Member Election
#                </a>
#               </li>
#              </ul>
#             </div>
#            </section>
#            <section class="primary_left_col_list" id="StudentEngagement">
#             <header>
#              <h2 data-target="StudentEngagement">
#               Student Engagement
#              </h2>
#             </header>
#             <div class="subNavWrapper">
#              <ul class="cl_iconNav">
#               <li>
#                <a href="http://marylandpublicschools.org/stateboard/Documents/2020/0901/Maryland-Recovery-Plan-Education-Student-Engagement.pdf" title="State Board of Education Presentation on Student Engagement, September 1, 2020">
#                 State Board of Education Presentation on Student Engagement, September 1, 2020
#                </a>
#               </li>
#               <li>
#                <a href="/stateboard/Documents/2020/0901/MSDE_Student_Engagement_Adopted_9.1.2020.pdf" title="Student Engagement Recommendations Adopted by the State Board, September 1, 2020">
#                 Student Engagement Recommendations Adopted by the State Board, September 1, 2020
#                </a>
#               </li>
#              </ul>
#             </div>
#            </section>
#            <section class="primary_left_col_list" id="ProceduresforAppealstotheStateBoard">
#             <header>
#              <h2 data-target="ProceduresforAppealstotheStateBoard">
#               Procedures for Appeals to the State Board
#              </h2>
#             </header>
#             <div class="subNavWrapper">
#              <ul class="cl_iconNav">
#               <li>
#                <a href="/stateboard/Documents/AppealsFilingProcess.pdf" title="How to File an Appeal (August 2021)">
#                 How to File an Appeal (August 2021)
#                </a>
#               </li>
#               <li>
#                <a href="http://www.dsd.state.md.us/COMAR/SubtitleSearch.aspx?search=13A.01.05.*" title="Code of Maryland Regulations (COMAR) 13A.01.05 - Appeals to the State Board of Education">
#                 Code of Maryland Regulations (COMAR) 13A.01.05 - Appeals to the State Board of Education
#                </a>
#               </li>
#              </ul>
#             </div>
#            </section>
#            <section class="primary_left_col_list" id="Meetings">
#             <header>
#              <h2 data-target="Meetings">
#               Meetings
#              </h2>
#             </header>
#             <div class="subNavWrapper">
#              <ul class="cl_iconNav">
#               <li>
#                <a href="/stateboard/Pages/Meetings-2022.aspx" title="2022 Board Meetings">
#                 2022 Board Meetings
#                </a>
#               </li>
#               <li>
#                <a href="/stateboard/Pages/PublicComment.aspx" title="Guidelines and Procedures for Public Comment">
#                 Guidelines and Procedures for Public Comment
#                </a>
#               </li>
#               <li>
#                <a href="/stateboard/Pages/archives.aspx" title="Archived Meeting Materials and Minutes">
#                 Archived Meeting Materials and Minutes
#                </a>
#               </li>
#              </ul>
#             </div>
#            </section>
#            <section class="primary_left_col_list" id="CommitteesandTaskForces">
#             <header>
#              <h2 data-target="CommitteesandTaskForces">
#               Committees and Task Forces
#              </h2>
#             </header>
#             <div class="subNavWrapper">
#              <ul class="cl_iconNav">
#               <li>
#                <a href="/stateboard/Pages/AAEEBB/index.aspx" title="Task Force on Achieving Academic Equity and Excellence for Black Boys">
#                 Task Force on Achieving Academic Equity and Excellence for Black Boys
#                </a>
#               </li>
#               <li>
#                <a href="/stateboard/Pages/TFSDR/index.aspx" title="Task Force on Student Discipline Regulations">
#                 Task Force on Student Discipline Regulations
#                </a>
#               </li>
#              </ul>
#             </div>
#            </section>
#            <section class="primary_left_col_list" id="Regulations">
#             <header>
#              <h2 data-target="Regulations">
#               Regulations
#              </h2>
#             </header>
#             <div class="subNavWrapper">
#              <ul class="cl_iconNav">
#               <li>
#                <a href="/about/Pages/Regulations/COMAR.aspx" title="Regulations and Regulatory Review">
#                 Regulations and Regulatory Review
#                </a>
#               </li>
#               <li>
#                <a href="/about/Pages/Regulations/emergency.aspx" title="Emergency Regulations">
#                 Emergency Regulations
#                </a>
#               </li>
#               <li>
#                <a href="/about/Pages/Regulations/proposed.aspx" title="Proposed Regulations">
#                 Proposed Regulations
#                </a>
#               </li>
#               <li>
#                <a href="/about/Pages/Regulations/SmallBusinesses.aspx" title="Regulations Impacting Small Businesses">
#                 Regulations Impacting Small Businesses
#                </a>
#               </li>
#              </ul>
#             </div>
#            </section>
#            <section class="primary_left_col_list" id="LegalOpinionsandOrders">
#             <header>
#              <h2 data-target="LegalOpinionsandOrders">
#               Legal Opinions and Orders
#              </h2>
#             </header>
#             <div class="subNavWrapper">
#              <ul class="cl_iconNav">
#               <li>
#                <a href="/stateboard/Pages/Legal-Opinions-Issued-by-the-Board.aspx" title="Legal Opinions Issued">
#                 Legal Opinions Issued
#                </a>
#               </li>
#               <li>
#                <a href="/stateboard/Pages/Orders-Issued-by-the-Board.aspx" title="Orders Issued">
#                 Orders Issued
#                </a>
#               </li>
#               <li>
#                <a href="/stateboard/Pages/Accessibility.aspx" title="Accessibility of State Board Opinions">
#                 Accessibility of State Board Opinions
#                </a>
#               </li>
#              </ul>
#             </div>
#            </section>
#            <section class="primary_left_col_list" id="AuditReports">
#             <header>
#              <h2 data-target="AuditReports">
#               Audit Reports
#              </h2>
#             </header>
#             <div class="subNavWrapper">
#              <ul class="cl_iconNav">
#               <li>
#                <a href="http://www.marylandpublicschools.org/stateboard/Documents/PGCPSGraduationRateAudit2018.pdf" title="2018 Prince George’s County Public Schools Performance Audit">
#                 2018 Prince George’s County Public Schools Performance Audit
#                </a>
#               </li>
#               <li>
#                <a href="/stateboard/Documents/PGCPSGraduationRateReview10312017.pdf" title="2017 Prince George’s County Public Schools Performance Audit">
#                 2017 Prince George’s County Public Schools Performance Audit
#                </a>
#               </li>
#              </ul>
#             </div>
#            </section>
#            <section class="primary_left_col_list" id="AdditionalRelatedLinks">
#             <header>
#              <h2 data-target="AdditionalRelatedLinks">
#               Additional Related Links
#              </h2>
#             </header>
#             <div class="subNavWrapper">
#              <ul class="cl_iconNav">
#               <li>
#                <a href="/stateboard/Pages/StudentDisciplineLongTermSuspension.aspx" title="Student Discipline and Long‐Term Suspension">
#                 Student Discipline and Long‐Term Suspension
#                </a>
#               </li>
#              </ul>
#             </div>
#            </section>
#           </div>
#           <div class="mdgov_contentWrapper">
#            <!--Custom Content Area-->
#            <div id="ctl00_PlaceHolderMain_ctl01_label" style="display:none">
#             Left_Content
#            </div>
#            <div aria-labelledby="ctl00_PlaceHolderMain_ctl01_label" class="ms-rtestate-field" id="ctl00_PlaceHolderMain_ctl01__ControlWrapper_RichHtmlField" style="display:inline">
#            </div>
#            <!--   -Custom Content Area-->
#           </div>
#          </div>
#          <!--End primary_left_col-->
#          <div class="span9" id="primary_right_col">
#           <!--Start primary_right_col-->
#           <div class="mdgov_contentWrapper">
#            <!--Custom Content Area-->
#            <div id="ctl00_PlaceHolderMain_editmodepanel2">
#             <h1>
#              State Board 2018 Meeting Calendar, Agendas, &amp; Minutes
#             </h1>
#            </div>
#            <div id="ctl00_PlaceHolderMain_ctl02_label" style="display:none">
#             Main_Content
#            </div>
#            <div aria-labelledby="ctl00_PlaceHolderMain_ctl02_label" class="ms-rtestate-field" id="ctl00_PlaceHolderMain_ctl02__ControlWrapper_RichHtmlField" style="display:inline">
#             <div style="text-align:left;">
#              <a href="/stateboard/Documents/2018BoardMeetingDates.pdf" title="2018 Board Meeting Dates">
#               2018 Board Meeting Dates
#              </a>
#              <a href="/stateboard/Documents/2018BoardMeetingDates.pdf" title="2018 Board Meeting Dates">
#               <img alt="" class="ms-asset-icon ms-rtePosition-4" src="/_layouts/images/icpdf.png"/>
#              </a>
#             </div>
#             <table border="1" bordercolor="#000000" cellpadding="10" cellspacing="0" style="height:1396px;width:600px;">
#              <tbody>
#               <tr bgcolor="#ffcc66">
#                <td bgcolor="#0072C6" colspan="3" style="height:28px;">
#                 <div align="center">
#                  <h3>
#                   <span class="ms-rteThemeForeColor-1-0">
#                    State Board 2018 Meeting Calendar, Agendas, and Minutes
#                   </span>
#                  </h3>
#                 </div>
#                </td>
#               </tr>
#               <tr bgcolor="#ffff99">
#                <td bgcolor="#DDEEFF" style="height:44px;" width="236">
#                 <div align="center">
#                  <h3>
#                   Date
#                  </h3>
#                 </div>
#                </td>
#                <td bgcolor="#DDEEFF" style="height:44px;" width="155">
#                 <div align="center">
#                  <h3>
#                   Agenda
#                  </h3>
#                 </div>
#                 <strong>
#                 </strong>
#                </td>
#                <td bgcolor="#DDEEFF" style="width:163px;height:44px;">
#                 <div align="center">
#                  <h3>
#                   Minutes
#                  </h3>
#                 </div>
#                </td>
#               </tr>
#               <tr style="text-align:center;">
#                <td rowspan="1">
#                 ​
#                 <span>
#                  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                   <font color="#000000">
#                    <strong>
#                     January 29, 2018
#                     <br/>
#                    </strong>
#                    <font size="1">
#                     <span>
#                      <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                       <font color="#000000">
#                        <font size="1">
#                         Monday
#                        </font>
#                       </font>
#                      </font>
#                     </span>
#                    </font>
#                   </font>
#                  </font>
#                 </span>
#                </td>
#                <td rowspan="1">
#                 <font color="#000000" size="2">
#                  <font face="Verdana, Arial, Helvetica, sans-serif">
#                   <font color="#000000" size="2">
#                    <a href="/stateboard/Pages/meeting-agendas/2018-01-29.aspx" title=" January 29, 2018 Board Agenda">
#                     <font face="Verdana, Arial, Helvetica, sans-serif">
#                      January 29, 2018 Board Agenda
#                     </font>
#                    </a>
#                   </font>
#                  </font>
#                 </font>
#                </td>
#                <td rowspan="1" style="width:163px;">
#                 <a href="/stateboard/Documents/minutes/2018/January292018.pdf" title="January 29, 2018 Board Minutes​">
#                  January 29, 2018
#                  <br/>
#                  Board Minutes​
#                 </a>
#                </td>
#               </tr>
#               <tr>
#                <td>
#                 <div align="center">
#                  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                   <font color="#000000">
#                    <strong>
#                     January 30, 2018
#                     <br/>
#                    </strong>
#                    <font size="1">
#                     <span>
#                      <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                       <font color="#000000">
#                        <font size="1">
#                         Tuesday
#                        </font>
#                       </font>
#                      </font>
#                     </span>
#                    </font>
#                   </font>
#                  </font>
#                  <br/>
#                 </div>
#                </td>
#                <td style="text-align:center;">
#                 <div align="center">
#                  <div align="center">
#                   <font color="#000000" size="2">
#                    <font face="Verdana, Arial, Helvetica, sans-serif">
#                     <span>
#                      <span>
#                      </span>
#                     </span>
#                     <font color="#000000" size="2">
#                      <font face="Verdana, Arial, Helvetica, sans-serif">
#                       <span>
#                        <font color="#fff5ee" size="2">
#                         <span>
#                          <span>
#                           <font color="#fff5ee" face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                            <font color="#000000" size="2">
#                             <font face="Verdana, Arial, Helvetica, sans-serif">
#                              <font color="#000000" size="2">
#                               <font face="Verdana, Arial, Helvetica, sans-serif">
#                                <a href="/stateboard/Pages/meeting-agendas/2018-01-30.aspx" title="January 30, 2018 Board Agenda">
#                                 January 30, 2018 Board Agenda
#                                </a>
#                               </font>
#                              </font>
#                             </font>
#                            </font>
#                           </font>
#                          </span>
#                         </span>
#                        </font>
#                       </span>
#                      </font>
#                     </font>
#                     <br/>
#                    </font>
#                   </font>
#                  </div>
#                 </div>
#                 <a href="/stateboard/Pages/meeting-agendas/2016-02-11.aspx" title="February 11, 2016 Board Agenda">
#                 </a>
#                </td>
#                <td style="text-align:center;width:163px;">
#                 <div align="center">
#                  <div align="center">
#                   <font color="#000000" size="2">
#                    <font face="Verdana, Arial, Helvetica, sans-serif">
#                     <a href="/stateboard/Documents/minutes/2018/January302018.pdf" title="January 30, 2018 Board Minutes​">
#                      January 30, 2018
#                      <br/>
#                      Board Minutes​
#                     </a>
#                     <br/>
#                    </font>
#                   </font>
#                  </div>
#                 </div>
#                </td>
#               </tr>
#               <tr>
#                <td rowspan="1">
#                 <div align="center">
#                  <font color="#000000" face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                   <strong>
#                    February 27, 2018
#                   </strong>
#                  </font>
#                 </div>
#                 <div align="center">
#                  <font color="#000000" size="1">
#                   <span>
#                    <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                     <font color="#000000">
#                      <font size="1">
#                       <span>
#                        <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                         <font color="#000000">
#                          <font size="1">
#                           Tuesday
#                          </font>
#                         </font>
#                        </font>
#                       </span>
#                      </font>
#                     </font>
#                    </font>
#                   </span>
#                  </font>
#                 </div>
#                </td>
#                <td rowspan="1" style="text-align:center;">
#                 <a href="/stateboard/Pages/meeting-agendas/2018-02-27.aspx" title="February 27, 2018 Board Agenda">
#                  February 27, 2018 Board Agenda​
#                 </a>
#                </td>
#                <td rowspan="1" style="width:163px;text-align:center;">
#                 <a href="/stateboard/Documents/minutes/2018/February272018.pdf" title="February 27, 2018 Board Minutes">
#                  February 27, 2018 Board Minutes​
#                 </a>
#                </td>
#               </tr>
#               <tr style="text-align:center;">
#                <td rowspan="1">
#                 ​
#                 <span>
#                  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                   <font color="#000000">
#                    <strong>
#                     March 20, 2018
#                     <br/>
#                    </strong>
#                    <font size="1">
#                     Tuesday
#                    </font>
#                   </font>
#                  </font>
#                 </span>
#                </td>
#                <td rowspan="1">
#                 <span>
#                 </span>
#                 <a href="/stateboard/Pages/meeting-agendas/2018-03-20.aspx" title="March 20, 2018 Board Agenda​​">
#                  <span>
#                   March 20, 2018
#                   <br/>
#                   Board Agenda​
#                  </span>
#                  ​
#                 </a>
#                </td>
#                <td rowspan="1" style="width:163px;">
#                 ​
#                 <a href="/stateboard/Documents/minutes/2018/March202018.pdf" title="March 20, 2018 Board Minutes">
#                  March 20, 2018
#                  <br/>
#                  Board Minutes
#                 </a>
#                </td>
#               </tr>
#               <tr>
#                <td rowspan="1">
#                 ​
#                 <div align="center">
#                  <strong>
#                   <font color="#000000" face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                    April 24, 2018
#                   </font>
#                  </strong>
#                 </div>
# ...
#                 <a href="/stateboard/Pages/meeting-agendas/2018-08-28.aspx" title="August 28, 2018 Board Agenda">
#                  August 28, 2018
#                  <br/>
#                  Board Agenda​
#                 </a>
#                </td>
#                <td rowspan="1" style="width:163px;">
#                 ​
#                 <span>
#                  <span>
#                  </span>
#                  <a href="/stateboard/Documents/minutes/2018/August282018.pdf" title="August 28, 2018 Board Minutes">
#                   <span>
#                    August 28
#                   </span>
#                   , 2018
#                   <br/>
#                   Board Minutes
#                  </a>
#                 </span>
#                </td>
#               </tr>
#               <tr style="text-align:center;">
#                <td rowspan="1">
#                 ​
#                 <span>
#                  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                   <font color="#000000">
#                    <strong>
#                     September 25, 2018
#                     <br/>
#                    </strong>
#                    <font size="1">
#                     <span>
#                      <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                       <font color="#000000" size="1">
#                        Tuesday
#                       </font>
#                      </font>
#                     </span>
#                    </font>
#                   </font>
#                  </font>
#                 </span>
#                </td>
#                <td rowspan="1">
#                 <span>
#                 </span>
#                 <a href="/stateboard/Pages/meeting-agendas/2018-09-25.aspx" title="September 25, 2018 Board Agenda​">
#                  <span>
#                   September 25, 2018
#                   <br/>
#                   Board Agenda​
#                  </span>
#                  ​
#                 </a>
#                </td>
#                <td rowspan="1" style="width:163px;">
#                 ​
#                 <span>
#                  <span>
#                  </span>
#                  <span>
#                   <span>
#                   </span>
#                  </span>
#                  <a href="/stateboard/Documents/minutes/2018/September252018.pdf" title="September 25, 2018 Board Minutes">
#                   <span>
#                    <span>
#                     September 25, 2018
#                    </span>
#                   </span>
#                   <br/>
#                   Board Minutes
#                  </a>
#                 </span>
#                </td>
#               </tr>
#               <tr>
#                <td>
#                 <div align="center">
#                  <font color="#000000" face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                   <strong>
#                    October 23, 2018
#                   </strong>
#                  </font>
#                 </div>
#                 <div align="center">
#                  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                   <font color="#000000" size="1">
#                    <span>
#                     <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                      <font color="#000000" size="1">
#                       Tuesday
#                      </font>
#                     </font>
#                    </span>
#                   </font>
#                  </font>
#                 </div>
#                </td>
#                <td style="text-align:center;">
#                 <span>
#                  <font color="#fff5ee" face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                  </font>
#                 </span>
#                 <span>
#                  <span>
#                   <a href="/stateboard/Pages/meeting-agendas/2018-10-23.aspx" title="October 23, 2018 Board Agenda">
#                    October 23, 2018
#                    <br/>
#                    Board Agenda
#                   </a>
#                   ​
#                  </span>
#                 </span>
#                 <br/>
#                </td>
#                <td style="width:163px;text-align:center;">
#                 <a href="/stateboard/Documents/minutes/2018/October232018.pdf" title="October 23, 2018 Board Minutes">
#                  October 23, 2018
#                  <br/>
#                  Board Minutes
#                 </a>
#                </td>
#               </tr>
#               <tr style="text-align:center;">
#                <td rowspan="1">
#                 <span>
#                  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                   <font color="#000000">
#                    <strong>
#                     December 4, 2018
#                     <br/>
#                    </strong>
#                    <font size="1">
#                     <span>
#                      <font face="Verdana, Arial, Helvetica, sans-serif" size="2">
#                       <font color="#000000" size="1">
#                        Tuesday
#                       </font>
#                      </font>
#                     </span>
#                    </font>
#                   </font>
#                  </font>
#                 </span>
#                 ​
#                </td>
#                <td rowspan="1">
#                 ​
#                 <a href="/stateboard/Pages/meeting-agendas/2018-12-04.aspx" title="December 04, 2018 Board Agenda">
#                  December 04, 2018 Board Agenda
#                 </a>
#                </td>
#                <td rowspan="1" style="width:163px;">
#                 ​
#                 <a href="/stateboard/Documents/minutes/2018/December042018.pdf" title="December 4, 2018 Board Minutes">
#                  December 4, 2018
#                  <br/>
#                  Board Minutes
#                 </a>
#                </td>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#            <!--  Custom Content Area-->
#           </div>
#           <div class="mdgov_contentWrapper">
#            <!--Custom WebPart-->
#            <div class="row-WPZone">
#             <menu class="ms-hide">
#              <ie:menuitem iconsrc="/_layouts/15/images/HelpIcon.gif" id="MSOMenu_Help" onmenuclick="MSOWebPartPage_SetNewWindowLocation(MenuWebPart.getAttribute('helpLink'), MenuWebPart.getAttribute('helpMode'))" style="display:none" text="Help" type="option">
#              </ie:menuitem>
#             </menu>
#            </div>
#            <!--Custom WebPart-->
#           </div>
#           <div class="mdgov_contentWrapper">
#            <!--Custom Content Area-->
#            <div id="ctl00_PlaceHolderMain_ctl03_label" style="display:none">
#             Center_Content
#            </div>
#            <div aria-labelledby="ctl00_PlaceHolderMain_ctl03_label" class="ms-rtestate-field" id="ctl00_PlaceHolderMain_ctl03__ControlWrapper_RichHtmlField" style="display:inline">
#             <p>
#              ​
#              <span>
#               <a href="/stateboard/Documents/PublicCommentGuidelines.pdf">
#                <strong>
#                 Guidelines and Procedures for Public Comment.
#                </strong>
#               </a>
#              </span>
#             </p>
#            </div>
#            <!--Custom Content Area-->
#           </div>
#           <div class="mdgov_contentWrapper">
#            <!--Custom WebPart-->
#            <div class="row-WPZone">
#            </div>
#            <!--Custom WebPart-->
#           </div>
#          </div>
#          <!--End primary_right_col-->
#         </div>
#         <!--End primary_content_Block-->
#        </div>
#        <div id="EditPageProperties">
#        </div>
#        <div id="hidZone" style="display:none">
#        </div>
#        <div class="row-fluid">
#         <div class="clearfix" id="footer_block">
#          <div class="span9">
#           <div id="footer_left">
#            <div class="cl_base_hNav footerLinks">
#             <!--  Add agency footer links -->
#             <!--  Add agency footer links -->
#             <ul>
#              <li>
#               <a href="https://news.maryland.gov/msde/contactmsde">
#                Contact Us
#               </a>
#              </li>
#              <li>
#               <a href="/Pages/privacy.aspx">
#                Privacy
#               </a>
#              </li>
#              <li class="last-child">
#               <a href="http://marylandpublicschools.org/Pages/Accessibility.aspx">
#                Accessibility
#               </a>
#              </li>
#              <li>
#               <a href="http://www.maryland.gov/pages/aup_linking.aspx" title="Maryland.gov Acceptable Use &amp; Linking Policy">
#                Terms of Use
#               </a>
#              </li>
#              <li>
#               <a href="http://marylandpublicschools.org/about/Pages/NonDiscrimination.aspx" title="Non-Discrimination Statement">
#                Non-Discrimination Statement
#               </a>
#              </li>
#             </ul>
#            </div>
#            <!-- Add agency address and phone -->
#            <p>
#             200 West Baltimore Street, Baltimore, MD 21201-2595
#            </p>
#            <p>
#             410-767-0100
#            </p>
#            <p>
#             © 2022 Maryland State Department of Education
#            </p>
#           </div>
#          </div>
#          <div class="span3">
#           <div class="clearfix" id="footer_right">
#            <div class="mdgov_socialNav">
#             <!-- configure footer social media icons and links -->
#             <ul class="cl_base_hNav cl_socialNav">
#              <li>
#               <a class="sm-facebook" href="http://www.facebook.com/MdPublicSchools" title="Facebook">
#                Facebook
#               </a>
#              </li>
#              <li>
#               <a class="sm-twitter" href="http://twitter.com/MdPublicSchools" title="Twitter">
#                Twitter
#               </a>
#              </li>
#              <!-- <li><a href="#" class="sm-googleplus" title="Google+">Google Plus</a></li>-->
#              <!--  <li><a href="#" class="sm-flickr" title="Flickr">Flickr</a></li>-->
#              <li>
#               <a class="sm-youtube" href="https://www.youtube.com/channel/UCzGBHwAQzzay6lVJafnholw" title="YouTube">
#                YouTube
#               </a>
#              </li>
#              <li>
#               <a class="sm-enewsletter" href="http://marylandpublicschools.org/about/Pages/OCP/Newsroom/index.aspx" title="eNewsletter">
#                eNewsletter
#               </a>
#              </li>
#              <li>
#               <a class="sm-all" href="http://www.maryland.gov/pages/social_media.aspx" title="MD Social Media Directory">
#                MD Social Media Directory
#               </a>
#              </li>
#             </ul>
#             <!--if no agy social media,replace above UL with code below-->
#             <!--<ul class="cl_base_hNav cl_socialNavDirectory">
#                             			<li><a href="http://www.maryland.gov/pages/social_media.aspx" class="sm-directory" title="MD Social Media Directory">MD Social Media Directory</a></li>
#                         				</ul>-->
#             <!-- Adding more links below the social icons -->
#            </div>
#            <div class="cl_base_hNav footerLinks">
#             <br/>
#             <ul>
#              <li>
#               <a href="/about/Pages/Regulations/index.aspx">
#                Regulations
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/about/Pages/directory.aspx">
#                Maryland Public Education Directory
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!-- ============== Global navigation ================================================================================= -->
#      <!-- ============== Search Control ==================================================================================== -->
#      <!-- ============== SP Reqs DeltaPlaceHolderPageTitleInTitleArea and PlaceHolderPageTitleInTitleArea for adding Apps in Site Content =================== -->
#      <!-- ============== Current navigation =========================================================================================== -->
#      <!-- ============== SP Reqs PlaceHolderLeftNavBar for adding Apps in Site Content =================== -->
#      <!-- ============== Needed for form stuff ========================================================================================= -->
#      <script type="text/javascript">
#       //<![CDATA[
#         var formDigestElement = document.getElementsByName('__REQUESTDIGEST')[0];
#         if (!((formDigestElement == null) || (formDigestElement.tagName.toLowerCase() != 'input') || (formDigestElement.type.toLowerCase() != 'hidden') ||
#             (formDigestElement.value == null) || (formDigestElement.value.length <= 0)))
#         {
#             formDigestElement.value = '0xB08000A00E03B2B42B9E52488C004F50909BE071E8CC62FB17D6A47645FDD95F9225F9F1D57B1D3CABA0AA842A3312EC76BEE0ED9368869FD7D4F5A62BD76A98,14 Jul 2022 19:50:02 -0000';
#             g_updateFormDigestPageLoaded = new Date();
#         }
#         //]]>
#      </script>
#      <!-- ============== Hidden Placeholders =========================================================================================== -->
#      <!-- ============== Adds extra stuff like another form for Survey management ====================================================== -->
#      <!-- This script provides the push/pop sliding action found in the responsive mobile menu -->
#      <script src="/_layouts/15/MDResponsiveToolKit/egov/js/base.js">
#      </script>
#      <script type="text/javascript">
#       //<![CDATA[
# var _spFormDigestRefreshInterval = 1440000;window.g_updateFormDigestPageLoaded = new Date(); window.g_updateFormDigestPageLoaded.setDate(window.g_updateFormDigestPageLoaded.getDate() -5);var _fV4UI = true;
# function _RegisterWebPartPageCUI()
# {
#     var initInfo = {editable: false,isEditMode: false,allowWebPartAdder: false,listId: "{64027f88-9b58-4f91-872a-80455082791b}",itemId: 128,recycleBinEnabled: true,enableMinorVersioning: true,enableModeration: false,forceCheckout: true,rootFolderUrl: "\u002fstateboard\u002fPages",itemPermissions:{High:16,Low:196673}};
#     SP.Ribbon.WebPartComponent.registerWithPageManager(initInfo);
#     var wpcomp = SP.Ribbon.WebPartComponent.get_instance();
#     var hid;
#     hid = document.getElementById("_wpSelected");
#     if (hid != null)
#     {
#         var wpid = hid.value;
#         if (wpid.length > 0)
#         {
#             var zc = document.getElementById(wpid);
#             if (zc != null)
#                 wpcomp.selectWebPart(zc, false);
#         }
#     }
#     hid = document.getElementById("_wzSelected");
#     if (hid != null)
#     {
#         var wzid = hid.value;
#         if (wzid.length > 0)
#         {
#             wpcomp.selectWebPartZone(null, wzid);
#         }
#     }
# };
# function __RegisterWebPartPageCUI() {
# ExecuteOrDelayUntilScriptLoaded(_RegisterWebPartPageCUI, "sp.ribbon.js");}
# _spBodyOnLoadFunctionNames.push("__RegisterWebPartPageCUI");var __wpmExportWarning='This Web Part Page has been personalized. As a result, one or more Web Part properties may contain confidential information. Make sure the properties contain information that is safe for others to read. After exporting this Web Part, view properties in the Web Part description file (.WebPart) by using a text editor such as Microsoft Notepad.';var __wpmCloseProviderWarning='You are about to close this Web Part.  It is currently providing data to other Web Parts, and these connections will be deleted if this Web Part is closed.  To close this Web Part, click OK.  To keep this Web Part, click Cancel.';var __wpmDeleteWarning='You are about to permanently delete this Web Part.  Are you sure you want to do this?  To delete this Web Part, click OK.  To keep this Web Part, click Cancel.';//]]>
#      </script>
#      <!-- DoIT-FAQ .js -->
#      <script src="/Style Library/egov/js/DoIT-FAQ.js" type="text/javascript">
#      </script>
#     </div>
#    </div>
#   </form>
#  </body>
# </html>

# %%
#find the highest category that contains all the info I want
tbody = doc.find("tbody")

# %%
for url in tbody.find_all("a"):
    print(url)
# Out:
# <a href="/stateboard/Pages/meeting-agendas/2018-01-29.aspx" title=" January 29, 2018 Board Agenda"><font face="Verdana, Arial, Helvetica, sans-serif">January 29, 2018 Board Agenda</font></a>
# <a href="/stateboard/Documents/minutes/2018/January292018.pdf" title="January 29, 2018 Board Minutes​">January 29, 2018<br/>Board Minutes​</a>
# <a href="/stateboard/Pages/meeting-agendas/2018-01-30.aspx" title="January 30, 2018 Board Agenda">January 30, 2018 Board Agenda</a>
# <a href="/stateboard/Pages/meeting-agendas/2016-02-11.aspx" title="February 11, 2016 Board Agenda"></a>
# <a href="/stateboard/Documents/minutes/2018/January302018.pdf" title="January 30, 2018 Board Minutes​">January 30, 2018<br/>Board Minutes​</a>
# <a href="/stateboard/Pages/meeting-agendas/2018-02-27.aspx" title="February 27, 2018 Board Agenda">February 27, 2018 Board Agenda​</a>
# <a href="/stateboard/Documents/minutes/2018/February272018.pdf" title="February 27, 2018 Board Minutes">February 27, 2018 Board Minutes​</a>
# <a href="/stateboard/Pages/meeting-agendas/2018-03-20.aspx" title="March 20, 2018 Board Agenda​​"><span>March 20, 2018<br/>Board Agenda​</span>​</a>
# <a href="/stateboard/Documents/minutes/2018/March202018.pdf" title="March 20, 2018 Board Minutes">March 20, 2018<br/>Board Minutes</a>
# <a href="/stateboard/Pages/meeting-agendas/2018-04-24.aspx" title="April 24, 2018 Board Agenda​">April 24, 2018<br/>Board Agenda​​</a>
# <a href="/stateboard/Documents/minutes/2018/April242018.pdf" title="April 24, 2018 Board Minutes">April 24, 2018<br/>Board Minutes</a>
# <a href="/stateboard/Pages/meeting-agendas/2018-05-22.aspx" title="May 22, 2018 Board Agenda​​">May 22, 2018<br/>Board Agenda​​</a>
# <a href="/stateboard/Documents/minutes/2018/May222018.pdf" title="May 22, 2018 Board Minutes">May 22, 2018<br/>Board Minutes</a>
# <a href="/stateboard/Pages/meeting-agendas/2018-06-20.aspx" title="June 20, 2018 Board Agenda​​​">June 20, 2018<br/>Board Agenda​​​</a>
# <a href="/stateboard/Documents/minutes/2018/June202018.pdf" title="June 20, 2018 Board Minutes">June 20, 2018<br/>Board Minutes</a>
# <a href="/stateboard/Pages/meeting-agendas/2018-07-24.aspx" title="July 24, 2018 Board Agenda">July 24, 2018<br/>Board Agenda</a>
# <a href="/stateboard/Documents/minutes/2018/July242018.pdf" title="July 24, 2018 Board Minutes">July 24, 2018<br/>Board Minutes</a>
# <a href="/stateboard/Pages/meeting-agendas/2018-08-28.aspx" title="August 28, 2018 Board Agenda">August 28, 2018<br/>Board Agenda​</a>
# <a href="/stateboard/Documents/minutes/2018/August282018.pdf" title="August 28, 2018 Board Minutes"><span>August 28</span>, 2018<br/>Board Minutes</a>
# <a href="/stateboard/Pages/meeting-agendas/2018-09-25.aspx" title="September 25, 2018 Board Agenda​"><span>September 25, 2018<br/>Board Agenda​</span>​</a>
# <a href="/stateboard/Documents/minutes/2018/September252018.pdf" title="September 25, 2018 Board Minutes"><span><span>September 25, 2018</span></span><br/>Board Minutes</a>
# <a href="/stateboard/Pages/meeting-agendas/2018-10-23.aspx" title="October 23, 2018 Board Agenda">October 23, 2018<br/>Board Agenda</a>
# <a href="/stateboard/Documents/minutes/2018/October232018.pdf" title="October 23, 2018 Board Minutes">October 23, 2018<br/>Board Minutes</a>
# <a href="/stateboard/Pages/meeting-agendas/2018-12-04.aspx" title="December 04, 2018 Board Agenda">December 04, 2018 Board Agenda</a>
# <a href="/stateboard/Documents/minutes/2018/December042018.pdf" title="December 4, 2018 Board Minutes">December 4, 2018<br/>Board Minutes</a>

# %%
for url in tbody.find_all("a"):
    
    if "Agenda" in url["title"]:
        print(url["title"])
        print(url["href"])
    
    if "Minutes" in url["title"]:
        print(url["title"])
        print(url["href"])
    
        print ("----")
# Out:
#  January 29, 2018 Board Agenda
# /stateboard/Pages/meeting-agendas/2018-01-29.aspx
# January 29, 2018 Board Minutes​
# /stateboard/Documents/minutes/2018/January292018.pdf
# ----
# January 30, 2018 Board Agenda
# /stateboard/Pages/meeting-agendas/2018-01-30.aspx
# February 11, 2016 Board Agenda
# /stateboard/Pages/meeting-agendas/2016-02-11.aspx
# January 30, 2018 Board Minutes​
# /stateboard/Documents/minutes/2018/January302018.pdf
# ----
# February 27, 2018 Board Agenda
# /stateboard/Pages/meeting-agendas/2018-02-27.aspx
# February 27, 2018 Board Minutes
# /stateboard/Documents/minutes/2018/February272018.pdf
# ----
# March 20, 2018 Board Agenda​​
# /stateboard/Pages/meeting-agendas/2018-03-20.aspx
# March 20, 2018 Board Minutes
# /stateboard/Documents/minutes/2018/March202018.pdf
# ----
# April 24, 2018 Board Agenda​
# /stateboard/Pages/meeting-agendas/2018-04-24.aspx
# April 24, 2018 Board Minutes
# /stateboard/Documents/minutes/2018/April242018.pdf
# ----
# May 22, 2018 Board Agenda​​
# /stateboard/Pages/meeting-agendas/2018-05-22.aspx
# May 22, 2018 Board Minutes
# /stateboard/Documents/minutes/2018/May222018.pdf
# ----
# June 20, 2018 Board Agenda​​​
# /stateboard/Pages/meeting-agendas/2018-06-20.aspx
# June 20, 2018 Board Minutes
# /stateboard/Documents/minutes/2018/June202018.pdf
# ----
# July 24, 2018 Board Agenda
# /stateboard/Pages/meeting-agendas/2018-07-24.aspx
# July 24, 2018 Board Minutes
# /stateboard/Documents/minutes/2018/July242018.pdf
# ----
# August 28, 2018 Board Agenda
# /stateboard/Pages/meeting-agendas/2018-08-28.aspx
# August 28, 2018 Board Minutes
# /stateboard/Documents/minutes/2018/August282018.pdf
# ----
# September 25, 2018 Board Agenda​
# /stateboard/Pages/meeting-agendas/2018-09-25.aspx
# September 25, 2018 Board Minutes
# /stateboard/Documents/minutes/2018/September252018.pdf
# ----
# October 23, 2018 Board Agenda
# /stateboard/Pages/meeting-agendas/2018-10-23.aspx
# October 23, 2018 Board Minutes
# /stateboard/Documents/minutes/2018/October232018.pdf
# ----
# December 04, 2018 Board Agenda
# /stateboard/Pages/meeting-agendas/2018-12-04.aspx
# December 4, 2018 Board Minutes
# /stateboard/Documents/minutes/2018/December042018.pdf
# ----

# %%
#save that info - the dataframe as a list of dictionary
#complete the url
#!= is not
#[:-14] take 14 characters from the tail to be removed - without that, it shows the title of the url
#agenda = None / minutes = None are the empty variable to be filled when "if" is met
#"empty" these variable at the end of the thrid "if" to reset for the next row in the loop

urls = []

agenda = None
minutes = None

for url in tbody.find_all("a"):
    date = (url["title"][:-14])
    if "Agenda" in url["title"]:
        agenda = "https://www.marylandpublicschools.org" + (url["href"])
        
    if "Minutes" in url["title"]:
        minutes = "https://www.marylandpublicschools.org" + (url["href"])   
   

    if agenda != None and minutes != None:
        url = {
                "date": date,
                "agenda" : agenda,
                "minutes" : minutes
            }
        
        urls.append(url)
        
        agenda = None
        minutes = None
    
df = pd.DataFrame(urls)
df
# Out:
#                   date                                             agenda  \
# 0    January 29, 2018   https://www.marylandpublicschools.org/stateboa...
# 1    January 30, 2018   https://www.marylandpublicschools.org/stateboa...
# 2    February 27, 2018  https://www.marylandpublicschools.org/stateboa...
# 3       March 20, 2018  https://www.marylandpublicschools.org/stateboa...
# 4       April 24, 2018  https://www.marylandpublicschools.org/stateboa...
# 5         May 22, 2018  https://www.marylandpublicschools.org/stateboa...
# 6        June 20, 2018  https://www.marylandpublicschools.org/stateboa...
# 7        July 24, 2018  https://www.marylandpublicschools.org/stateboa...
# 8      August 28, 2018  https://www.marylandpublicschools.org/stateboa...
# 9   September 25, 2018  https://www.marylandpublicschools.org/stateboa...
# 10    October 23, 2018  https://www.marylandpublicschools.org/stateboa...
# 11    December 4, 2018  https://www.marylandpublicschools.org/stateboa...
#
#                                               minutes
# 0   https://www.marylandpublicschools.org/stateboa...
# 1   https://www.marylandpublicschools.org/stateboa...
# 2   https://www.marylandpublicschools.org/stateboa...
# 3   https://www.marylandpublicschools.org/stateboa...
# 4   https://www.marylandpublicschools.org/stateboa...
# 5   https://www.marylandpublicschools.org/stateboa...
# 6   https://www.marylandpublicschools.org/stateboa...
# 7   https://www.marylandpublicschools.org/stateboa...
# 8   https://www.marylandpublicschools.org/stateboa...
# 9   https://www.marylandpublicschools.org/stateboa...
# 10  https://www.marylandpublicschools.org/stateboa...
# 11  https://www.marylandpublicschools.org/stateboa...

# %%
from urllib.request import urlretrieve

# %%
#check the first dic of the list
urls[0]
# Out:
# {'date': 'January 29, 2018 ',
#  'agenda': 'https://www.marylandpublicschools.org/stateboard/Pages/meeting-agendas/2018-01-29.aspx',
#  'minutes': 'https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/January292018.pdf'}

# %%
#urls is a list of dictionaries
#A/B: save to A folder with the file name B
# + is to concatenate
for info in urls:
    print("Downloading", info["agenda"])
    urlretrieve(info["agenda"], filename = "Agenda/" + info["date"])
    
    
    print("Downloading", info["minutes"])
    urlretrieve(info["minutes"], filename = "Minutes/" + info["date"])
# Out:
# Downloading https://www.marylandpublicschools.org/stateboard/Pages/meeting-agendas/2018-01-29.aspx
# Downloading https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/January292018.pdf
# Downloading https://www.marylandpublicschools.org/stateboard/Pages/meeting-agendas/2016-02-11.aspx
# Downloading https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/January302018.pdf
# Downloading https://www.marylandpublicschools.org/stateboard/Pages/meeting-agendas/2018-02-27.aspx
# Downloading https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/February272018.pdf
# Downloading https://www.marylandpublicschools.org/stateboard/Pages/meeting-agendas/2018-03-20.aspx
# Downloading https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/March202018.pdf
# Downloading https://www.marylandpublicschools.org/stateboard/Pages/meeting-agendas/2018-04-24.aspx
# Downloading https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/April242018.pdf
# Downloading https://www.marylandpublicschools.org/stateboard/Pages/meeting-agendas/2018-05-22.aspx
# Downloading https://www.marylandpublicschools.org/stateboard/Documents/minutes/2018/May222018.pdf
# Downloading https://www.marylandpublicschools.org/stateboard/Pages/meeting-agendas/2018-06-20.aspx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [90], in <cell line: 4>()
#       4 for info in urls:
#       5     print("Downloading", info["agenda"])
# ----> 6     urlretrieve(info["agenda"], filename = "Agenda/" + info["date"])
#       9     print("Downloading", info["minutes"])
#      10     urlretrieve(info["minutes"], filename = "Minutes/" + info["date"])
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/urllib/request.py:270, in urlretrieve(url, filename, reporthook, data)
#     267     reporthook(blocknum, bs, size)
#     269 while True:
# --> 270     block = fp.read(bs)
#     271     if not block:
#     272         break
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:
